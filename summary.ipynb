# %%
import numpy as np
import pandas as pd

import matplotlib as mpl
import matplotlib.pyplot as plt

import seaborn as sns
import seaborn.objects as so

sns.set_theme()

# %%
df = pd.read_csv("data/salaries_cyber.csv")

# %%
df
# Out:
#       work_year experience_level employment_type
# 0          2022               EN              FT  \
# 1          2022               MI              FT
# 2          2022               MI              FT
# 3          2022               MI              FT
# 4          2022               EN              CT
# ...         ...              ...             ...
# 1242       2020               MI              FT
# 1243       2021               SE              FT
# 1244       2021               SE              FT
# 1245       2021               MI              FT
# 1246       2021               MI              FT
#
#                          job_title  salary salary_currency  salary_in_usd
# 0            Cyber Program Manager   63000             USD          63000  \
# 1                 Security Analyst   95000             USD          95000
# 2                 Security Analyst   70000             USD          70000
# 3              IT Security Analyst  250000             BRL          48853
# ...

# %%
df.isnull().sum()
# Out:
# work_year             0
# experience_level      0
# employment_type       0
# job_title             0
# salary                0
# salary_currency       0
# salary_in_usd         0
# employee_residence    0
# remote_ratio          0
# company_location      0
# company_size          0
# dtype: int64

# %%
df.nunique()
# Out:
# work_year               3
# experience_level        4
# employment_type         4
# job_title              87
# salary                384
# salary_currency        21
# salary_in_usd         579
# employee_residence     58
# remote_ratio            3
# company_location       55
# company_size            3
# dtype: int64

# %%
df.shape
# Out:
# (1247, 11)

# %%
sns.histplot(data=df, x="salary_in_usd")
plt.show()

# %%
sns.boxplot(x="experience_level", y="salary_in_usd", data=df)
sns.stripplot(x="experience_level", y="salary_in_usd", data=df, hue="experience_level", jitter = True,  dodge=True, alpha=.5, zorder=1)
plt.show()

# %%
sns.boxplot(x="company_size", y="salary_in_usd", data=df)
sns.stripplot(x="company_size", y="salary_in_usd", data=df, hue="company_size", jitter = True,  dodge=True, alpha=.5, zorder=1)
plt.show()

# %%
f, axs = plt.subplots(1, 3, figsize=(18, 8))
sns.histplot(x="experience_level", data=df, ax=axs[0], stat="frequency")
sns.histplot(x="company_size", data=df, ax=axs[1], color=sns.color_palette("hls", 8)[3], stat="frequency")
sns.histplot(x="employment_type", data=df, ax=axs[2], color=sns.color_palette("hls", 8)[0], stat="frequency")
plt.show()

# %%
sns.heatmap(data=df.corr(numeric_only=True), annot=True, cmap="Blues")
plt.show()
